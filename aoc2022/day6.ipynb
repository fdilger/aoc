# %%
i = '''mjqjpqmgbljsphdztnvjfqwrcgsmlb'''
i = '''bvwbjplbgvbhsrlpgdmjqwftvncz'''
i = '''...'''
i = list(i)
i
# Out:
# ['r',
#  'h',
#  'g',
#  'h',
#  'w',
#  'w',
#  's',
#  'm',
#  's',
#  'g',
#  'm',
#  'g',
#  's',
#  'm',
#  'm',
#  'm',
#  'l',
#  'z',
#  'l',
#  'j',
#  'l',
#  'l',
#  'r',
#  'd',
#  'd',
#  'v',
#  's',
#  'v',
#  'h',
#  'v',
#  'h',
#  'h',
#  'n',
#  'v',
#  'v',
#  'r',
#  'c',
#  'c',
#  'c',
#  'w',
#  'h',
#  'h',
#  'v',
#  'g',
#  'g',
#  'h',
#  'c',
#  'h',
#  'w',
#  'h',
#  'v',
#  'w',
#  'v',
#  'c',
#  'v',
#  'r',
#  'r',
#  'r',
#  'g',
#  't',
#  'g',
#  'r',
#  'g',
#  'd',
#  'g',
#  'g',
#  'f',
#  'd',
#  'g',
#  'f',
#  'f',
#  's',
#  'h',
#  's',
#  'l',
#  'l',
#  'v',
#  'v',
#  's',
#  'l',
#  's',
#  'p',
#  'p',
#  'g',
#  'l',
#  'g',
#  'v',
#  'g',
#  'w',
#  'g',
#  's',
#  'w',
#  'w',
#  'c',
#  'b',
#  'c',
#  'w',
#  'b',
#  'w',
#  'r',
#  'r',
#  'b',
#  'j',
#  'b',
#  'w',
#  'j',
#  'j',
#  't',
#  'g',
#  'j',
#  'j',
#  'd',
#  'z',
#  'd',
#  'f',
#  'd',
#  'h',
#  'f',
#  'd',
#  'd',
#  'r',
#  'm',
#  'm',
#  'h',
#  'q',
# ...

# %%
for k in range(len(i)-14):
    if len(set(i[k:k+14])) == 14:
         print(k+14)
         break
# Out:
# 3263
