A Z
B Z
B Y
B Y
B Y
B Z
B Y
B Y
B Y
A X
A Y
B Z
C X
A Y
A Y
B Y
B Z
C X
A X
A Y
B X
B Y
A Y
A Z
A X
A Z
A Y
C Z
A Y
B Y
B Y
B Z
C X
B Z
A Z
B Y
B Z
B Y
A Y
A Y
C Z
A Y
B Z
B Y
B Y
A X
B Y
A Y
B Y
A Y
A Y
C X
A Y
B Y
A Y
C X
B X
A Y
B Z
A Y
A Y
C Z'''

i = i.splitlines()
i1 = [k.split(' ') for k in i]
i2 = [k.split(' ') for k in i]

for k in i2:
    for j in range(len(k)):
        if k[j] == 'X':
            k[j] = 'A'
        if k[j] == 'Y':
            k[j] = 'B'
        if k[j] == 'Z':
            k[j] = 'C'

for k in i1:
    for j in range(len(k)):
        if k[j] == 'A':
            k[j] = 0
        if k[j] == 'B':
            k[j] = 1
        if k[j] == 'C':
            k[j] = 2
for k in i1:
    for j in range(len(k)):
        if k[j] == 'X':
            k[j] = ((k[j-1]-1)  % 3)
        if k[j] == 'Y':
            k[j] = k[j-1]
        if k[j] == 'Z':
            k[j] = (k[j-1] + 1) %3

for k in i1:
    for j in range(len(k)):
        if k[j] == 0:
            k[j] = 'A'
        if k[j] == 1:
            k[j] = 'B'
        if k[j] == 2:
            k[j] = 'C'


i1
# Out:
# [['B', 'A'],
#  ['B', 'B'],
#  ['A', 'A'],
#  ['B', 'B'],
#  ['B', 'B'],
#  ['A', 'A'],
#  ['A', 'C'],
#  ['A', 'A'],
#  ['C', 'B'],
#  ['A', 'A'],
#  ['A', 'A'],
#  ['B', 'B'],
#  ['B', 'C'],
#  ['A', 'A'],
#  ['B', 'C'],
#  ['B', 'C'],
#  ['B', 'C'],
#  ['B', 'B'],
#  ['A', 'B'],
#  ['A', 'A'],
#  ['B', 'A'],
#  ['A', 'B'],
#  ['A', 'B'],
#  ['A', 'B'],
#  ['B', 'C'],
#  ['A', 'A'],
#  ['A', 'B'],
#  ['C', 'B'],
#  ['B', 'C'],
#  ['A', 'A'],
#  ['B', 'C'],
#  ['B', 'B'],
#  ['A', 'A'],
#  ['A', 'A'],
#  ['A', 'A'],
#  ['A', 'A'],
#  ['A', 'B'],
#  ['C', 'B'],
#  ['C', 'A'],
#  ['A', 'A'],
#  ['A', 'A'],
#  ['A', 'C'],
#  ['C', 'B'],
#  ['B', 'C'],
#  ['B', 'B'],
#  ['B', 'B'],
#  ['A', 'A'],
#  ['C', 'B'],
#  ['A', 'A'],
#  ['B', 'C'],
#  ['B', 'C'],
#  ['A', 'A'],
#  ['B', 'B'],
#  ['B', 'C'],
#  ['A', 'A'],
#  ['C', 'B'],
#  ['B', 'B'],
#  ['A', 'A'],
#  ['A', 'A'],
#  ['A', 'A'],
#  ['A', 'A'],
#  ['B', 'C'],
#  ['B', 'A'],
#  ['A', 'A'],
#  ['B', 'B'],
#  ['A', 'B'],
# ...

# %%
'A' < 'B'
# Out:
# True

# %%
def game_result(l):
    u=(l[0],l[1])
    match u:
        case ('A','A'):
            return 3+1
        case ('B','B'):
            return 3+2
        case ('C','C'):
            return 3+3
        case ('A','B'):
            return 6+2
        case ('A','C'):
            return 0+3
        case ('B','A'):
            return 0+1
        case ('B','C'):
            return 6+3
        case ('C','A'):
            return 6+1
        case ('C','B'):
            return 0+2

# %%
sum([game_result(l) for l in i1])
# Out:
# 12989
